# %% [markdown]
# <a href="https://colab.research.google.com/github/pdivya-mca/Guvi-Codekatta-Programs-Python/blob/main/Input_Output_1_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **GUVI CODEKATA Input/Output Question 1 to 10**

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format

# %%
# Question 1
a=int(input())
print(a)
# Out:
# 2
# 2

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format

# %%
# Question 2
a=input().split()
b=map(int,a)
print(*b)
# Out:
# 2 3 4 5 6 7 8
# 2 3 4 5 6 7 8

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format

# %%
# Question 3
a=input().split()
b=input().split()

d=map(int,a)
e=map(int,b)

print(*a)
print(*b)
# Out:
# 5 3
# 1 2 3 4 5
# 5 3
# 1 2 3 4 5

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format

# %%
#Question 4
a=input().split()
b=input().split()
c=input().split()

d=map(int,a)
e=map(int,b)
f=map(int,c)

print(*a)
print(*b)
print(*c)
# Out:
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4
# 2 4

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format

# %%
#Question 5
a=input().split()
b=input().split()
c=input().split()

d=map(int,a)
e=map(int,b)
f=map(int,c)

print(*d,*e,*f)
# Out:
# 2
# 4
# 5
# 2 4 5

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format

# %%
#Question 6
a=input().split()
b=input().split()
c=input().split()

d=map(int,a)
e=map(int,b)
f=map(int,c)

print(*a)
print(*b)
print(*c)
# Out:
# 2 5
# 2 5 6
# 2 4 5
# 2 5
# 2 5 6
# 2 4 5

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format

# %%
#Question 7
a=input()
b=list(map(str,a))

print(*b)
# Out:
# guvi
# g u v i

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format.

# %%
#Question 8
a=input().split()
for i in a:
  print(i)
# Out:
# 2.3 4.5 7.8
# 2.3
# 4.5
# 7.8

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format.

# %%
#Question 9
s=input()
for i in s:
    print(i)
# Out:
# guvigeek
# g
# u
# v
# i
# g
# e
# e
# k

# %% [markdown]
# Write a code to get the input in the given format and print the output in the given format.

# %%
#Question 10
a=input()
b=list(map(str,a))
print(*b,sep=",")
# Out:
# guvi
# g,u,v,i
